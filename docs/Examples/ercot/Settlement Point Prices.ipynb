# %% [markdown]
# # Settlement Point Prices

# %%
import gridstatus
import pandas as pd

# %%
iso = gridstatus.Ercot()

# %% [markdown]
# ## The get_spp Method

# %% [markdown]
# The main method is `get_spp`, which takes the following arguments:

# %% [markdown]
# ### Date
#
# Date can be `"today"`, `"latest"`, or a `pandas.Timestamp`.

# %% [markdown]
# ### Market
#
# ERCOT has 2 available markets:

# %%
iso.markets
# Out:
# [<Markets.REAL_TIME_15_MIN: 'REAL_TIME_15_MIN'>,
#  <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>]

# %% [markdown]
# ### Location Type
#
# ERCOT has 3 available location types, with `"ZONE"` as default.

# %%
iso.location_types
# Out:
# ['HUB', 'NODE', 'ZONE']

# %% [markdown]
# ## Example: Fetch latest real-time market (RTM) by zone

# %%
df = iso.get_spp(
    date="latest",
    market="REAL_TIME_15_MIN",
    location_type="zone"
)
df
# Out:
#       Location                      Time            Market Location Type  \
# 0         DC_E 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 1         DC_L 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 2         DC_N 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 3         DC_R 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 4         DC_S 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 5       LZ_AEN 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 6       LZ_CPS 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 7   LZ_HOUSTON 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 8      LZ_LCRA 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 9     LZ_NORTH 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 10    LZ_RAYBN 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 11    LZ_SOUTH 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
# 12     LZ_WEST 2022-12-21 20:45:00-06:00  REAL_TIME_15_MIN          Zone
#
#       SPP
# 0   24.73
# 1   26.11
# 2   10.00
# 3   25.74
# 4   38.17
# 5   25.15
# 6   25.50
# 7   25.07
# 8   24.96
# 9   24.42
# 10  24.71
# 11  25.26
# 12   9.76

# %% [markdown]
# ## Example: Fetch latest day-ahead market (DAM) by hub

# %%
df = iso.get_spp(
    date="latest",
    market="DAY_AHEAD_HOURLY",
    location_type="hub"
)
df
# Out:
#      Location                      Time            Market Location Type    SPP
# 0  HB_HOUSTON 2022-12-21 23:00:00-06:00  DAY_AHEAD_HOURLY           Hub  20.01
# 1    HB_NORTH 2022-12-21 23:00:00-06:00  DAY_AHEAD_HOURLY           Hub  17.40
# 2      HB_PAN 2022-12-21 23:00:00-06:00  DAY_AHEAD_HOURLY           Hub   7.62
# 3    HB_SOUTH 2022-12-21 23:00:00-06:00  DAY_AHEAD_HOURLY           Hub  24.03
# 4     HB_WEST 2022-12-21 23:00:00-06:00  DAY_AHEAD_HOURLY           Hub  16.44

# %% [markdown]
# ## Example: Fetch DAM from 2 days ago by node

# %%
date = pd.Timestamp.now() - pd.Timedelta(days=2)
df = iso.get_spp(
    date=date,
    market="REAL_TIME_15_MIN",
    location_type="node"
)
df
# Out:
#            Location                      Time            Market Location Type  \
# 0              AEEC 2022-12-19 23:30:00-06:00  REAL_TIME_15_MIN          Node
# 1      AGUAYO_UNIT1 2022-12-19 23:30:00-06:00  REAL_TIME_15_MIN          Node
# 2       AJAXWIND_RN 2022-12-19 23:30:00-06:00  REAL_TIME_15_MIN          Node
# 3      ALGOD_ALL_RN 2022-12-19 23:30:00-06:00  REAL_TIME_15_MIN          Node
# 4          ALVIN_RN 2022-12-19 23:30:00-06:00  REAL_TIME_15_MIN          Node
# ...             ...                       ...               ...           ...
# 76090   WOV_BESS_RN 2022-12-19 00:00:00-06:00  REAL_TIME_15_MIN          Node
# 76091  WRSBES_BESS1 2022-12-19 00:00:00-06:00  REAL_TIME_15_MIN          Node
# 76092  W_PECO_UNIT1 2022-12-19 00:00:00-06:00  REAL_TIME_15_MIN          Node
# 76093      X443ESRN 2022-12-19 00:00:00-06:00  REAL_TIME_15_MIN          Node
# 76094   YNG_WND_ALL 2022-12-19 00:00:00-06:00  REAL_TIME_15_MIN          Node
#
#          SPP
# 0      31.83
# 1      31.83
# 2      31.83
# 3      31.83
# 4      31.83
# ...      ...
# 76090   1.57
# 76091   2.53
# 76092   2.38
# 76093  26.88
# 76094   3.37
#
# [76095 rows x 5 columns]
