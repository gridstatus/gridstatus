# %% [markdown]
# # IESO Load Examples
#
# Retrieves data from the Independent Electricity System Operator of Canada. https://www.ieso.ca/

# %%
import pandas as pd
import gridstatus
from gridstatus.ieso import IESO

ieso = IESO()
print(gridstatus.list_isos())
# Out:
#                                       Name     Id  Class
# 0                         Midcontinent ISO   miso   MISO
# 1                           California ISO  caiso  CAISO
# 2                                      PJM    pjm    PJM
# 3    Electric Reliability Council of Texas  ercot  Ercot
# 4                     Southwest Power Pool    spp    SPP
# 5                             New York ISO  nyiso  NYISO
# 6                          ISO New England  isone  ISONE
# 7  Independent Electricity System Operator   ieso   IESO

# %% [markdown]
# ## Get Hourly Load
#
# Hourly load for the market and Ontario. From http://reports.ieso.ca/public/RealtimeConstTotals/

# %%
# All data from IESO is in the EST timezone year-round meaning no changes for DST.
today = pd.Timestamp.now().tz_localize("EST").date()
load = ieso.get_load(today)
load.head(10)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00, 11.67it/s]
#              Interval Start              Interval End  Market Total Load  \
# 0 2023-12-27 00:00:00-05:00 2023-12-27 01:00:00-05:00        15_580.5417
# 1 2023-12-27 01:00:00-05:00 2023-12-27 02:00:00-05:00        15_020.5250
# 2 2023-12-27 02:00:00-05:00 2023-12-27 03:00:00-05:00        14_556.2750
# 3 2023-12-27 03:00:00-05:00 2023-12-27 04:00:00-05:00        14_509.6083
# 4 2023-12-27 04:00:00-05:00 2023-12-27 05:00:00-05:00        14_543.5417
# 5 2023-12-27 05:00:00-05:00 2023-12-27 06:00:00-05:00        15_330.7167
# 6 2023-12-27 06:00:00-05:00 2023-12-27 07:00:00-05:00        16_304.5083
# 7 2023-12-27 07:00:00-05:00 2023-12-27 08:00:00-05:00        17_228.5083
# 8 2023-12-27 08:00:00-05:00 2023-12-27 09:00:00-05:00        17_765.1667
# 9 2023-12-27 09:00:00-05:00 2023-12-27 10:00:00-05:00        17_836.2583
#
#    Ontario Load
# 0   12_904.6167
# 1   12_488.7667
# 2   12_297.0833
# 3   12_316.9667
# 4   12_504.7417
# 5   12_890.6833
# 6   13_723.3250
# 7   14_466.0833
# 8   15_086.0000
# 9   15_574.6833

# %% [markdown]
# ## Get Five Minute Load
#
# Same as the `get_load` except every 5 minutes.

# %%
load_5_minutes = ieso.get_5_min_load(today)
load_5_minutes.tail(5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00, 12.01it/s]
#                Interval Start              Interval End  \
# 171 2023-12-27 14:15:00-05:00 2023-12-27 14:20:00-05:00
# 172 2023-12-27 14:20:00-05:00 2023-12-27 14:25:00-05:00
# 173 2023-12-27 14:25:00-05:00 2023-12-27 14:30:00-05:00
# 174 2023-12-27 14:30:00-05:00 2023-12-27 14:35:00-05:00
# 175 2023-12-27 14:35:00-05:00 2023-12-27 14:40:00-05:00
#
#                Published Time  Market Total Load  Ontario Load
# 171 2023-12-27 14:38:17-05:00        18_496.0000   16_475.5000
# 172 2023-12-27 14:38:17-05:00        18_445.4000   16_427.9000
# 173 2023-12-27 14:38:17-05:00        18_468.7000   16_455.9000
# 174 2023-12-27 14:38:17-05:00        18_471.9000   16_456.0000
# 175 2023-12-27 14:38:17-05:00        18_488.6000   16_472.1000

# %% [markdown]
# ## Load Forecast
#
# Gets the load forecast for Ontario, East, and West up to 34 days in the future. From http://reports.ieso.ca/public/OntarioZonalDemand/

# %%
two_weeks_from_now = today + pd.Timedelta(days=14)
load_forecast = ieso.get_load_forecast(two_weeks_from_now)
load_forecast.head(10)
# Out:
#              Interval Start              Interval End  \
# 0 2024-01-10 00:00:00-05:00 2024-01-10 01:00:00-05:00
# 1 2024-01-10 01:00:00-05:00 2024-01-10 02:00:00-05:00
# 2 2024-01-10 02:00:00-05:00 2024-01-10 03:00:00-05:00
# 3 2024-01-10 03:00:00-05:00 2024-01-10 04:00:00-05:00
# 4 2024-01-10 04:00:00-05:00 2024-01-10 05:00:00-05:00
# 5 2024-01-10 05:00:00-05:00 2024-01-10 06:00:00-05:00
# 6 2024-01-10 06:00:00-05:00 2024-01-10 07:00:00-05:00
# 7 2024-01-10 07:00:00-05:00 2024-01-10 08:00:00-05:00
# 8 2024-01-10 08:00:00-05:00 2024-01-10 09:00:00-05:00
# 9 2024-01-10 09:00:00-05:00 2024-01-10 10:00:00-05:00
#
#              Published Time  Ontario Load Forecast  East Load Forecast  \
# 0 2023-12-27 09:01:09-05:00            18_129.0000         17_488.0000
# 1 2023-12-27 09:01:09-05:00            17_379.0000         16_757.0000
# 2 2023-12-27 09:01:09-05:00            16_950.0000         16_337.0000
# 3 2023-12-27 09:01:09-05:00            16_753.0000         16_146.0000
# 4 2023-12-27 09:01:09-05:00            16_708.0000         16_104.0000
# 5 2023-12-27 09:01:09-05:00            16_902.0000         16_303.0000
# 6 2023-12-27 09:01:09-05:00            17_592.0000         17_004.0000
# 7 2023-12-27 09:01:09-05:00            19_088.0000         18_487.0000
# 8 2023-12-27 09:01:09-05:00            20_619.0000         19_987.0000
# 9 2023-12-27 09:01:09-05:00            20_768.0000         20_105.0000
#
#    West Load Forecast
# 0            641.0000
# 1            622.0000
# 2            613.0000
# 3            607.0000
# 4            604.0000
# 5            599.0000
# 6            588.0000
# 7            601.0000
# 8            632.0000
# 9            663.0000
