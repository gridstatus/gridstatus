# %%
import gridstatus
nyiso = gridstatus.NYISO()
nyiso.get_lmp(date="today", market="REAL_TIME_5_MIN", locations="ALL")
# Out:
#                           Time            Interval Start  \
# 0    2023-12-04 00:00:00-05:00 2023-12-04 00:00:00-05:00
# 1    2023-12-04 00:00:00-05:00 2023-12-04 00:00:00-05:00
# 2    2023-12-04 00:00:00-05:00 2023-12-04 00:00:00-05:00
# 3    2023-12-04 00:00:00-05:00 2023-12-04 00:00:00-05:00
# 4    2023-12-04 00:00:00-05:00 2023-12-04 00:00:00-05:00
# ...                        ...                       ...
# 4075 2023-12-04 23:55:00-05:00 2023-12-04 23:55:00-05:00
# 4076 2023-12-04 23:55:00-05:00 2023-12-04 23:55:00-05:00
# 4077 2023-12-04 23:55:00-05:00 2023-12-04 23:55:00-05:00
# 4078 2023-12-04 23:55:00-05:00 2023-12-04 23:55:00-05:00
# 4079 2023-12-04 23:55:00-05:00 2023-12-04 23:55:00-05:00
#
#                   Interval End           Market Location Location Type    LMP  \
# 0    2023-12-04 00:05:00-05:00  REAL_TIME_5_MIN   CAPITL          Zone  24.53
# 1    2023-12-04 00:05:00-05:00  REAL_TIME_5_MIN   CENTRL          Zone  23.05
# 2    2023-12-04 00:05:00-05:00  REAL_TIME_5_MIN   DUNWOD          Zone  24.50
# 3    2023-12-04 00:05:00-05:00  REAL_TIME_5_MIN   GENESE          Zone  22.53
# 4    2023-12-04 00:05:00-05:00  REAL_TIME_5_MIN      H Q          Zone  23.68
# ...                        ...              ...      ...           ...    ...
# 4075 2023-12-05 00:00:00-05:00  REAL_TIME_5_MIN    NORTH          Zone  30.93
# 4076 2023-12-05 00:00:00-05:00  REAL_TIME_5_MIN      NPX          Zone  30.40
# 4077 2023-12-05 00:00:00-05:00  REAL_TIME_5_MIN      O H          Zone  29.36
# 4078 2023-12-05 00:00:00-05:00  REAL_TIME_5_MIN      PJM          Zone  30.13
# 4079 2023-12-05 00:00:00-05:00  REAL_TIME_5_MIN     WEST          Zone  30.16
#
#       Energy  Congestion  Loss
# 0      23.52         0.0  1.01
# 1      23.52         0.0 -0.47
# 2      23.51         0.0  0.99
# 3      23.52         0.0 -0.99
# 4      23.51         0.0  0.17
# ...      ...         ...   ...
# 4075   29.77         0.0  1.16
# 4076   29.77         0.0  0.63
# 4077   29.78         0.0 -0.42
# 4078   29.77         0.0  0.36
# 4079   29.77         0.0  0.39
#
# [4080 rows x 10 columns]

# %%
import gridstatus
caiso = gridstatus.CAISO()
locations = ["TH_NP15_GEN-APND", "TH_SP15_GEN-APND", "TH_ZP26_GEN-APND"]
caiso.get_lmp(date="today", market='DAY_AHEAD_HOURLY', locations=locations)
# Out:
#                         Time            Interval Start  \
# 0  2023-12-04 00:00:00-08:00 2023-12-04 00:00:00-08:00
# 1  2023-12-04 00:00:00-08:00 2023-12-04 00:00:00-08:00
# 2  2023-12-04 00:00:00-08:00 2023-12-04 00:00:00-08:00
# 3  2023-12-04 01:00:00-08:00 2023-12-04 01:00:00-08:00
# 4  2023-12-04 01:00:00-08:00 2023-12-04 01:00:00-08:00
# ..                       ...                       ...
# 67 2023-12-04 22:00:00-08:00 2023-12-04 22:00:00-08:00
# 68 2023-12-04 22:00:00-08:00 2023-12-04 22:00:00-08:00
# 69 2023-12-04 23:00:00-08:00 2023-12-04 23:00:00-08:00
# 70 2023-12-04 23:00:00-08:00 2023-12-04 23:00:00-08:00
# 71 2023-12-04 23:00:00-08:00 2023-12-04 23:00:00-08:00
#
#                 Interval End            Market          Location  \
# 0  2023-12-04 01:00:00-08:00  DAY_AHEAD_HOURLY  TH_NP15_GEN-APND
# 1  2023-12-04 01:00:00-08:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND
# 2  2023-12-04 01:00:00-08:00  DAY_AHEAD_HOURLY  TH_ZP26_GEN-APND
# 3  2023-12-04 02:00:00-08:00  DAY_AHEAD_HOURLY  TH_NP15_GEN-APND
# 4  2023-12-04 02:00:00-08:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND
# ..                       ...               ...               ...
# 67 2023-12-04 23:00:00-08:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND
# 68 2023-12-04 23:00:00-08:00  DAY_AHEAD_HOURLY  TH_ZP26_GEN-APND
# 69 2023-12-05 00:00:00-08:00  DAY_AHEAD_HOURLY  TH_NP15_GEN-APND
# 70 2023-12-05 00:00:00-08:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND
# 71 2023-12-05 00:00:00-08:00  DAY_AHEAD_HOURLY  TH_ZP26_GEN-APND
#
#    Location Type       LMP    Energy  Congestion     Loss
# 0    Trading Hub  59.88654  61.05887     0.00000 -1.17233
# 1    Trading Hub  59.37365  61.05887     0.00000 -1.68522
# 2    Trading Hub  59.05003  61.05887     0.00000 -2.00884
# 3    Trading Hub  57.37607  58.43967     0.00000 -1.06360
# 4    Trading Hub  56.81505  58.43967     0.00000 -1.62462
# ..           ...       ...       ...         ...      ...
# 67   Trading Hub  65.33878  67.21983     0.08177 -1.96282
# 68   Trading Hub  64.59264  67.21983     0.08177 -2.70896
# 69   Trading Hub  60.55107  62.32926    -0.12647 -1.65173
# 70   Trading Hub  60.67310  62.32926     0.07659 -1.73275
# 71   Trading Hub  59.83165  62.32926     0.07659 -2.57420
#
# [72 rows x 10 columns]

# %%
caiso.markets
# Out:
# [<Markets.REAL_TIME_5_MIN: 'REAL_TIME_5_MIN'>,
#  <Markets.REAL_TIME_15_MIN: 'REAL_TIME_15_MIN'>,
#  <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>]
