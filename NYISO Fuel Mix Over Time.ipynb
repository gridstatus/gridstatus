# %% [markdown]
# # NYISO Fuel Mix Over Time

# %%
import isodata
import pandas as pd
iso = isodata.NYISO()

# %%
df = iso.get_fuel_mix_today()
df
# Out:
# Fuel Category                      Time  Dual Fuel   Hydro  Natural Gas  \
# 0             2022-10-23 00:05:00-04:00     2076.0  1724.0       2103.0
# 1             2022-10-23 00:10:00-04:00     1910.0  1739.0       2065.0
# 2             2022-10-23 00:15:00-04:00     1936.0  1698.0       2066.0
# 3             2022-10-23 00:20:00-04:00     2026.0  1666.0       2076.0
# 4             2022-10-23 00:25:00-04:00     2065.0  1574.0       2079.0
# ..                                  ...        ...     ...          ...
# 239           2022-10-23 19:50:00-04:00     3553.0  2950.0       2744.0
# 240           2022-10-23 19:55:00-04:00     3540.0  2981.0       2733.0
# 241           2022-10-23 20:00:00-04:00     3529.0  2912.0       2758.0
# 242           2022-10-23 20:05:00-04:00     3528.0  2964.0       2741.0
# 243           2022-10-23 20:10:00-04:00     3516.0  3062.0       2708.0
#
# Fuel Category  Nuclear  Other Fossil Fuels  Other Renewables   Wind
# 0               3323.0                 0.0             246.0  921.0
# 1               3325.0                 0.0             246.0  939.0
# 2               3323.0                 0.0             245.0  964.0
# 3               3324.0                 0.0             246.0  970.0
# 4               3325.0                 0.0             246.0  981.0
# ..                 ...                 ...               ...    ...
# 239             3324.0                 0.0             246.0  461.0
# 240             3323.0                 0.0             246.0  441.0
# 241             3322.0                 0.0             244.0  458.0
# 242             3323.0                 0.0             244.0  460.0
# 243             3323.0                 0.0             245.0  455.0
#
# [244 rows x 8 columns]

# %%
# Get fuel mix
df = iso.get_historical_fuel_mix(start="Nov 1, 2017", end="Oct 22, 2022")
# Out:
# 100%|███████████████████████████████████████████| 60/60 [01:08<00:00,  1.14s/it]

# %%
data = df.set_index("Time").resample('MS').sum().reset_index()
data.head(10)
# Out:
# Fuel Category                      Time   Dual Fuel       Hydro  Natural Gas  \
# 0             2017-11-01 00:00:00-04:00  18959579.0  30447482.0   21914126.0
# 1             2017-12-01 00:00:00-05:00  26492744.0  30399671.0   26247968.0
# 2             2018-01-01 00:00:00-05:00  31903170.0  27668473.0   26511086.0
# 3             2018-02-01 00:00:00-05:00  15425092.0  26941421.0   23025745.0
# 4             2018-03-01 00:00:00-05:00  19666517.0  32764341.0   22999813.0
# 5             2018-04-01 00:00:00-04:00  19699877.0  30384362.0   24537954.0
# 6             2018-05-01 00:00:00-04:00  24745520.0  31193895.0   22509300.0
# 7             2018-06-01 00:00:00-04:00  29921618.0  27057113.0   25584381.0
# 8             2018-07-01 00:00:00-04:00  46345174.0  27594915.0   35905445.0
# 9             2018-08-01 00:00:00-04:00  50191808.0  27201483.0   37326637.0
#
# Fuel Category     Nuclear  Other Fossil Fuels  Other Renewables       Wind
# 0              44359507.0            417465.0         2459898.0  5366198.0
# 1              44349267.0           1426102.0         2419416.0  4839025.0
# 2              48802629.0           3627454.0         2141482.0  6163104.0
# 3              39918885.0            284680.0         2007094.0  5344987.0
# 4              43192132.0           1491575.0         2332648.0  4163407.0
# 5              34689734.0            297352.0         2355395.0  4523767.0
# 6              41533621.0            340653.0         2278286.0  3586994.0
# 7              46038444.0            204724.0         2334606.0  2597822.0
# 8              47102524.0           1947993.0         2433483.0  2486365.0
# 9              45460108.0           1215035.0         2452371.0  2505057.0

# %%
import plotly.express as px

fig = px.bar(data[1:-1], x="Time", y=df.columns[1:], title="Fuel Mix over Time in NYISO")
fig.show("svg")
